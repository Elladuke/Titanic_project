# %%
#Happy coding!

"""titanic_predictions.py: This program predicts whether a person survived if they 
were in the titanic"""

#__author__ = "Immanuella Duke"
# Out:
# 'titanic_predictions.py: This program predicts whether a person survived if they \nwere in the titanic'

# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
import csv
from sklearn import datasets, linear_model
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
#import dataset
train_data = pd.read_csv('train.csv')
new_train_data = train_data
#use age, gender, pclass as features and survived as y label

#preprocess data
#for gender

cleanup_gender = {"Sex": {"male": 0, "female": 1}}                



new_train_data.replace(cleanup_gender, inplace=True)
new_train_data['Age'] = pd.cut(new_train_data['Age'], 4, labels=[1, 2, 3, 4])
new_train_data

new_train_data = new_train_data.fillna(method = 'ffill')

train_X = pd.concat([new_train_data['Age'], new_train_data['Sex'], new_train_data['Pclass']], axis = 1)

train_Y = new_train_data['Survived']


new_train_data.head(30)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %%
#train model

#logistic regression

logfunc = LogisticRegression(solver = 'lbfgs')
logfunc.fit(train_X, train_Y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
#knn classifier
neigh = KNeighborsClassifier(n_neighbors=2)
neigh.fit(train_X, train_Y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=2, p=2,
#                      weights='uniform')

# %%
#random forest
#clf = RandomForestClassifier(n_estimators=100, max_depth=2, random_state=0)
#clf = AdaBoostClassifier(n_estimators=100)
clf = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0, max_depth=1, random_state=0)
clf.fit(train_X, train_Y)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#                            learning_rate=1.0, loss='deviance', max_depth=1,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=100,
#                            n_iter_no_change=None, presort='auto',
#                            random_state=0, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
#import test dataset
test_data =  pd.read_csv('test.csv')
new_test_data = test_data

#preprocess data
#for gender
cleanup_gender = {"Sex": {"male": 0, "female": 1}}                


new_test_data.replace(cleanup_gender, inplace=True)
new_test_data['Age'] = pd.cut(new_test_data['Age'], 4, labels=[1, 2, 3, 4])
print(len(new_test_data))


values = {'Age': 99, 'Sex': 99,'Pclass': 99}


new_test_data = new_test_data.fillna(method = 'ffill')

test_X = pd.concat([new_test_data['Age'], new_test_data['Sex'], new_test_data['Pclass']], axis = 1)
test_X

#prediction for logistic reg
pred_y = logfunc.predict(test_X)

#prediction for knn
pred_y2 = neigh.predict(test_X)

#prediction for clf
pred_y3 = clf.predict(test_X)
# Out:
# 418

# %%
submission = pd.DataFrame({'PassengerId':new_test_data['PassengerId'],'Survived':pred_y})

filename = 'predictions.csv'

submission.to_csv(filename,index=False)

print('Saved file: ' + filename)
# Out:
# Saved file: predictions.csv

# %%
submission = pd.DataFrame({'PassengerId':new_test_data['PassengerId'],'Survived':pred_y2})

filename = 'predictionsknn.csv'

submission.to_csv(filename,index=False)

print('Saved file: ' + filename)
# Out:
# Saved file: predictionsknn.csv

# %%
submission = pd.DataFrame({'PassengerId':new_test_data['PassengerId'],'Survived':pred_y3})

filename = 'predictionsrf.csv'

submission.to_csv(filename,index=False)

print('Saved file: ' + filename)
# Out:
# Saved file: predictionsrf.csv

# %%
#do cross validation on train set

# %%
#use linear regression

# %%
#use logistic regression

# %%
#use decision trees

# %%
#use knn

# %%
#use ensemble model

# %%
###########################
#do predictions on test data

# %%
#do predictions and measure accuracy for linear regr

# %%
#do predictions and measure accuracy for logistic regr

# %%
#do predictions and measure accuracy for decision trees

# %%
#do predictions and measure accuracy for knn

# %%
#do predictions and measure accuracy for ensemble
